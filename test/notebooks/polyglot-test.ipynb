# %% [markdown]
# Generate a hello-world example for each of these languages:
# - csharp
# - fsharp
# - powershell
# - javascript
# - sql
# - kql
# - mermaid
# - html

# %% [markdown]
# Here are hello-world examples for each of the languages you mentioned:
#
# **C# (CSharp):**

# %%
using System;

class HelloWorld
{
    static void Main()
    {
        Console.WriteLine("Hello, world!");
    }
}

# %% [markdown]
# **F# (FSharp):**

# %%
open System

printfn "Hello, world!"
# Out:
# Hello, world!

# %% [markdown]
# **PowerShell:**

# %%
Write-Host "Hello, world!"
# Out:
# Hello, world!

# %% [markdown]
# **JavaScript:**

# %%
console.log("Hello, world!");
# Out:
# Command cancelled.

# %% [markdown]
# **SQL:**

# %%
SELECT 'Hello, world!' AS HelloWorld;
# Out:
# <p>A SQL connection has not been established.</p>
# <p>To connect to a database, first add the SQL extension package by running the following in a C# cell:</p>
# <code>
#     <pre>
#     #r "nuget:Microsoft.DotNet.Interactive.SqlServer,*-*"
#     </pre>
# </code>
# Now, you can connect to a Microsoft SQL Server database by running the following in a C# cell:
# <code>
#     <pre>
#     #!connect mssql --kernel-name mydatabase "Persist Security Info=False; Integrated Security=true; Initial Catalog=MyDatabase; Server=localhost"
#     </pre>
# </code>
# <p>Once a connection is established, you can send SQL statements by prefixing them with the magic command for your connection.</p>
# <code>
#     <pre>
# #!sql-mydatabase
# SELECT 'Hello, world!' AS HelloWorld;
#     </pre>
# </code>
# SQL statements cannot be executed in this kernel.

# %% [markdown]
# **KQL (Kusto Query Language):**

# %%
print "Hello, world!"
# Out:
# <p>A KQL connection has not been established.</p>
# <p>To connect to a database, first add the KQL extension package by running the following in a C# cell:</p>
# <code>
#     <pre>
#     #r "nuget:Microsoft.DotNet.Interactive.Kql,*-*"
#     </pre>
# </code>
# Now, you can connect to a Microsoft Kusto Server database by running the following in a C# cell:
# <code>
#     <pre>
#     #!connect kql --kernel-name mydatabase --cluster "https://help.kusto.windows.net" --database "Samples"
#     </pre>
# </code>
# <p>Once a connection is established, you can send KQL statements by prefixing them with the magic command for your connection.</p>
# <code>
#     <pre>
# #!kql-mydatabase
# print "Hello, world!"
#     </pre>
# </code>
# KQL statements cannot be executed in this kernel.

# %% [markdown]
# **Mermaid:**
#
# Mermaid is a diagramming and charting tool that uses a markdown-like syntax. It doesn't have a direct "Hello, World!" example, but here's a simple flowchart example:

# %%
graph TD
    A[Start] --> B[Hello, world!]
    B --> C[End]
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="2c2b12a20fee454b8ed1baf0c9264ff1"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('2c2b12a20fee454b8ed1baf0c9264ff1');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_2c2b12a20fee454b8ed1baf0c9264ff1',
#                     `graph TD
#     A[Start] --> B[Hello, world!]
#     B --> C[End]`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# **HTML:**

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Hello, world!</title>title>
</head>head>
<body>
    <h1>Hello, world!</h1>h1>
</body>body>
</html>html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Hello, world!</title>title>
# </head>head>
# <body>
#     <h1>Hello, world!</h1>h1>
# </body>body>
# </html>html>

# %% [markdown]
# Generate the HTML for a nice looking marketing landing page for cosmetics products.

# %% [markdown]
# Here's a simple HTML template for a cosmetics marketing landing page:

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Cosmetics Landing Page</title>
    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
    <style>
        .hero {
            background-image: url('your-hero-image-url.jpg');
            background-size: cover;
            height: 100vh;
            display: flex;
            justify-content: center;
            align-items: center;
            text-align: center;
        }
        .hero h1 {
            font-size: 4rem;
            color: white;
        }
        .products {
            display: flex;
            justify-content: center;
            flex-wrap: wrap;
            margin: 2rem 0;
        }
        .product-card {
            width: 300px;
            margin: 1rem;
            padding: 1rem;
            border: 1px solid #ccc;
            border-radius: 5px;
        }
        .product-card img {
            width: 100%;
            height: auto;
        }
    </style>
</head>
<body>
    <header class="hero">
        <h1>Welcome to Our Cosmetics Store</h1>
    </header>

    <section class="container">
        <h2>Featured Products</h2>
        <div class="products">
            <div class="product-card">
                <img src="product-1.jpg" alt="Product 1">
                <h3>Product 1</h3>
                <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit.</p>
                <button class="btn btn-primary">Buy Now</button>
            </div>
            <div class="product-card">
                <img src="product-2.jpg" alt="Product 2">
                <h3>Product 2</h3>
                <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit.</p>
                <button class="btn btn-primary">Buy Now</button>
            </div>
            <div class="product-card">
                <img src="product-3.jpg" alt="Product 3">
                <h3>Product 3</h3>
                <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit.</p>
                <button class="btn btn-primary">Buy Now</button>
            </div>
        </div>
    </section>

    <footer class="text-center py-3">
        <p>&copy; 2022 Cosmetics Store. All rights reserved.</p>
    </footer>

    <script src="https://code.jquery.com/jquery-3.5.1.slim.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.9.3/dist/umd/popper.min.js"></script>
    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
</body>
</html>

# %% [markdown]
# This template uses the Bootstrap framework for styling. Replace the image URLs with your own images, and update the product information as needed.
